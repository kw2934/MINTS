# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/MINTS/'

import sys
sys.path.append(path[:-1])

from experiment import merge_and_plot_colab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
n_shards = 4
out_dir = path + 'results'
summary = merge_and_plot_colab(n_shards=n_shards, out_dir=out_dir)
# Out:
# Found 4 shard files:
#   /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_shard0_of4.npz  (25 seeds)
#   /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_shard1_of4.npz  (25 seeds)
#   /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_shard2_of4.npz  (25 seeds)
#   /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_shard3_of4.npz  (25 seeds)
# Merged 100 seeds from 4 shards → /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_merged_4shards.npz
#
# ================================================================================================================================================================================
#   Summary — 100 seeds, T=20000, K=12, sigma=1.0
#   theta = [0.  0.1 0.2 0.3 0.4 0.7 0.5 0.5 0.4 0.2 0.2 0.1]
# ================================================================================================================================================================================
#
#        t      MINTS (unstructured)          MINTS (unimodal)                       UCB         Thompson Sampling                      OSUB                       UTS                      OSSB
#   ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#     5000     358.9 ± 14.9             209.2 ± 15.2             357.5 ± 10.9             261.0 ± 31.0             186.0 ± 38.3             220.9 ± 75.8             529.9 ± 102.4
#    10000     399.9 ± 14.8             220.6 ± 15.0             425.9 ± 12.2             311.5 ± 50.8             226.4 ± 61.2             315.9 ± 144.5            887.9 ± 205.0
#    20000     436.4 ± 14.2             231.7 ± 14.4             489.8 ± 13.7             366.4 ± 84.6             278.4 ± 104.0            477.8 ± 281.9           1484.0 ± 393.9
# ================================================================================================================================================================================
#
# Saved /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_merged_4shards_plot_cdf.pdf  and  /content/drive/MyDrive/Colab Notebooks/MINTS/results/results_merged_4shards_plot_cdf.png
